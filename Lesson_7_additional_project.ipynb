# %% [markdown]
# ## Очищаем файл xlsx

# %%
path = 'shared/homeworks/python_ds_miniprojects/7_tables/tables.xlsx'

# %%
import pandas as pd

# %%
df = pd.read_excel(path)
df
# Out:
#    Unnamed: 0  company41  company51  company50  company76  company47  \
# 0         NaN        580        198        968        220        788
# 1         NaN        786        271         69        566        NaN
# 2         NaN        578        NaN        526         74        984
# 3         NaN        614        NaN        589        575         85
# 4         NaN         44        849        992        155        527
# 5         NaN        859        966        918        312        NaN
# 6         NaN        225        486         20        367        339
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# 8         NaN        NaN        NaN        NaN        NaN        NaN
# 9         NaN  company41  company51  company50  company76  company47
# 10        NaN        110        828        253        NaN        818
# 11        NaN        958        266        105        870        384
# 12        NaN        843         19        467        784        885
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0    object
# company41     object
# company51     object
# company50     object
# company76     object
# company47     object
# company27     object
# company48     object
# dtype: object

# %%
df = df[df['Unnamed: 0'].notna() | df.company41.notna() | df.company51.notna() | df.company50.notna() | df.company76.notna() | df.company47.notna() | df.company27.notna() | df.company48.notna()].reset_index()
df
# Out:
#     index Unnamed: 0  company41  company51  company50  company76  company47  \
# 0       0        NaN        580        198        968        220        788
# 1       1        NaN        786        271         69        566        NaN
# 2       2        NaN        578        NaN        526         74        984
# 3       3        NaN        614        NaN        589        575         85
# 4       4        NaN         44        849        992        155        527
# 5       5        NaN        859        966        918        312        NaN
# 6       6        NaN        225        486         20        367        339
# 7       9        NaN  company41  company51  company50  company76  company47
# 8      10        NaN        110        828        253        NaN        818
# 9      11        NaN        958        266        105        870        384
# 10     12        NaN        843         19        467        784        885
# ...

# %%
df = df.drop(columns = 'index')
df
# Out:
#    Unnamed: 0  company41  company51  company50  company76  company47  \
# 0         NaN        580        198        968        220        788
# 1         NaN        786        271         69        566        NaN
# 2         NaN        578        NaN        526         74        984
# 3         NaN        614        NaN        589        575         85
# 4         NaN         44        849        992        155        527
# 5         NaN        859        966        918        312        NaN
# 6         NaN        225        486         20        367        339
# 7         NaN  company41  company51  company50  company76  company47
# 8         NaN        110        828        253        NaN        818
# 9         NaN        958        266        105        870        384
# 10        NaN        843         19        467        784        885
# 11        NaN        143        583        NaN        NaN        716
# 12        NaN        499        469        666        887        142
# ...

# %%
for index, row in df.iterrows():
    if pd.notna(row['Unnamed: 0']):
        row.company48, row.company27, row.company47, row.company76, row.company50, row.company51, row.company41 = row.company27, row.company47, row.company76, row.company50, row.company51, row.company41, row['Unnamed: 0']

# %%
df
# Out:
#    Unnamed: 0  company41  company51  company50  company76  company47  \
# 0         NaN        580        198        968        220        788
# 1         NaN        786        271         69        566        NaN
# 2         NaN        578        NaN        526         74        984
# 3         NaN        614        NaN        589        575         85
# 4         NaN         44        849        992        155        527
# 5         NaN        859        966        918        312        NaN
# 6         NaN        225        486         20        367        339
# 7         NaN  company41  company51  company50  company76  company47
# 8         NaN        110        828        253        NaN        818
# 9         NaN        958        266        105        870        384
# 10        NaN        843         19        467        784        885
# 11        NaN        143        583        NaN        NaN        716
# 12        NaN        499        469        666        887        142
# ...

# %%
df = df.drop(columns = 'Unnamed: 0')
df
# Out:
#     company41  company51  company50  company76  company47  company27  \
# 0         580        198        968        220        788        554
# 1         786        271         69        566        NaN        193
# 2         578        NaN        526         74        984        581
# 3         614        NaN        589        575         85        122
# 4          44        849        992        155        527         33
# 5         859        966        918        312        NaN        404
# 6         225        486         20        367        339        481
# 7   company41  company51  company50  company76  company47  company27
# 8         110        828        253        NaN        818         15
# 9         958        266        105        870        384        NaN
# 10        843         19        467        784        885        870
# 11        143        583        NaN        NaN        716        671
# 12        499        469        666        887        142        487
# ...

# %%
df['a'] = df.company41.str.contains('company')
df
# Out:
#     company41  company51  company50  company76  company47  company27  \
# 0         580        198        968        220        788        554
# 1         786        271         69        566        NaN        193
# 2         578        NaN        526         74        984        581
# 3         614        NaN        589        575         85        122
# 4          44        849        992        155        527         33
# 5         859        966        918        312        NaN        404
# 6         225        486         20        367        339        481
# 7   company41  company51  company50  company76  company47  company27
# 8         110        828        253        NaN        818         15
# 9         958        266        105        870        384        NaN
# 10        843         19        467        784        885        870
# 11        143        583        NaN        NaN        716        671
# 12        499        469        666        887        142        487
# ...

# %%
df = df[df.a.isna() ]

# %%
df
# Out:
#    company41 company51 company50 company76 company47 company27 company48    a
# 0        580       198       968       220       788       554       479  NaN
# 1        786       271        69       566       NaN       193       636  NaN
# 2        578       NaN       526        74       984       581       951  NaN
# 3        614       NaN       589       575        85       122       454  NaN
# 4         44       849       992       155       527        33       NaN  NaN
# 5        859       966       918       312       NaN       404       407  NaN
# 6        225       486        20       367       339       481       252  NaN
# 8        110       828       253       NaN       818        15       752  NaN
# 9        958       266       105       870       384       NaN       NaN  NaN
# 10       843        19       467       784       885       870       177  NaN
# 11       143       583       NaN       NaN       716       671       907  NaN
# ...

# %%
df = df.drop(columns = 'a')
df
# Out:
#    company41 company51 company50 company76 company47 company27 company48
# 0        580       198       968       220       788       554       479
# 1        786       271        69       566       NaN       193       636
# 2        578       NaN       526        74       984       581       951
# 3        614       NaN       589       575        85       122       454
# 4         44       849       992       155       527        33       NaN
# 5        859       966       918       312       NaN       404       407
# 6        225       486        20       367       339       481       252
# 8        110       828       253       NaN       818        15       752
# 9        958       266       105       870       384       NaN       NaN
# 10       843        19       467       784       885       870       177
# 11       143       583       NaN       NaN       716       671       907
# 12       499       469       666       887       142       487        33
# ...

# %%
df = df.fillna(0)
df
# Out:
#     company41  company51  company50  company76  company47  company27  \
# 0         580        198        968        220        788        554
# 1         786        271         69        566          0        193
# 2         578          0        526         74        984        581
# 3         614          0        589        575         85        122
# 4          44        849        992        155        527         33
# 5         859        966        918        312          0        404
# 6         225        486         20        367        339        481
# 8         110        828        253          0        818         15
# 9         958        266        105        870        384          0
# 10        843         19        467        784        885        870
# 11        143        583          0          0        716        671
# 12        499        469        666        887        142        487
# 13        110        828        253        260        818         15
# ...

# %%
df.company41.sum()
# Out:
# 14918
