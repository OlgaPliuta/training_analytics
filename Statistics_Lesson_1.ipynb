# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
sns.set(rc={'figure.figsize':(20,10)})

# %%
df = pd.read_csv('games.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
df=df.dropna()#.reset_index(drop=True, inplace=True)
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.Year.describe()
# Out:
# count    16291.000000
# mean      2006.405561
# std          5.832412
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year, dtype: float64

# %%
ax = sns.distplot(df.Year)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.Platform.value_counts(normalize=True)*100
# Out:
# DS      13.080842
# PS2     13.056289
# PS3      8.004420
# Wii      7.918483
# X360     7.574735
# PSP      7.347615
# PS       7.298508
# PC       5.757780
# XB       4.929102
# GBA      4.824750
# GC       3.326990
# 3DS      3.063041
# PSV      2.516727
# PS4      2.062488
# N64      1.939721
# SNES     1.467068
# XOne     1.307470
# SAT      1.061936
# WiiU     0.877785
# 2600     0.712050
# NES      0.601559
# GB       0.595421
# DC       0.319195
# GEN      0.165736
# NG       0.073660
# SCD      0.036830
# WS       0.036830
# 3DO      0.018415
# TG16     0.012277
# PCFX     0.006138
# GG       0.006138
# Name: Platform, dtype: float64

# %%
pls = df.Platform.value_counts(normalize=True)*100 > 7
pls
# Out:
# DS       True
# PS2      True
# PS3      True
# Wii      True
# X360     True
# PSP      True
# PS       True
# PC      False
# XB      False
# GBA     False
# GC      False
# 3DS     False
# PSV     False
# PS4     False
# N64     False
# SNES    False
# XOne    False
# SAT     False
# WiiU    False
# 2600    False
# NES     False
# GB      False
# DC      False
# GEN     False
# NG      False
# SCD     False
# WS      False
# 3DO     False
# TG16    False
# PCFX    False
# GG      False
# Name: Platform, dtype: bool

# %%
pls.index
# Out:
# Index(['DS', 'PS2', 'PS3', 'Wii', 'X360', 'PSP', 'PS', 'PC', 'XB', 'GBA', 'GC',
#        '3DS', 'PSV', 'PS4', 'N64', 'SNES', 'XOne', 'SAT', 'WiiU', '2600',
#        'NES', 'GB', 'DC', 'GEN', 'NG', 'SCD', 'WS', '3DO', 'TG16', 'PCFX',
#        'GG'],
#       dtype='object')

# %%
pls['DS']
# Out:
# True

# %%
df1 = df[df.Platform.isin(['DS', 'PS2', 'PS3', 'Wii', 'X360', 'PSP', 'PS'])]
#df[df.Platform.value_counts(normalize=True)*100 > 7]
df1
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 6          7                              New Super Mario Bros.       DS
# 7          8                                           Wii Play      Wii
# ...      ...                                                ...      ...
# 16588  16591                                   Mega Brain Boost       DS
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16592  16595                                           Plushees       DS
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# ...

# %%
df.Publisher.value_counts()
# Out:
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          918
# Konami Digital Entertainment     823
#                                 ...
# CPG Products                       1
# Genterprise                        1
# Nichibutsu                         1
# Fields                             1
# Pony Canyon                        1
# Name: Publisher, Length: 576, dtype: int64

# %%
import scipy

# %%
scipy.stats.mode(df.Publisher)
# Out:
# ModeResult(mode=array(['Electronic Arts'], dtype=object), count=array([1339]))

# %%
nin = df[df.Publisher == 'Nintendo']
nin
# Out:
#         Rank                                               Name Platform  \
# 0          1                                         Wii Sports      Wii
# 1          2                                  Super Mario Bros.      NES
# 2          3                                     Mario Kart Wii      Wii
# 3          4                                  Wii Sports Resort      Wii
# 4          5                           Pokemon Red/Pokemon Blue       GB
# ...      ...                                                ...      ...
# 16269  16272                           Slide Adventure: Mag Kid       DS
# 16357  16360               Mario vs. Donkey Kong: Tipping Stars     WiiU
# 16456  16459                           Art Academy: Home Studio     WiiU
# 16473  16476                                    Captain Rainbow      Wii
# 16542  16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...      3DS
#
#          Year         Genre Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
nin.NA_Sales.median()
# Out:
# 0.375

# %%
nin.EU_Sales.median()
# Out:
# 0.12

# %%
nin.JP_Sales.median()
# Out:
# 0.28

# %%
nin.Other_Sales.median()
# Out:
# 0.03

# %%
nin.Global_Sales.median()
# Out:
# 0.92

# %%
scipy.stats.mode(df1.Publisher)
# Out:
# ModeResult(mode=array(['Electronic Arts'], dtype=object), count=array([848]))

# %%
ax = sns.boxplot(x=nin.Genre, y=nin.JP_Sales)

# %%
genres = ['Fighting', 'Simulation', 'Platform', 'Racing', 'Sports']
nin1 = nin.query('Genre in @genres')
nin1
# Out:
#         Rank                                          Name Platform    Year  \
# 0          1                                    Wii Sports      Wii  2006.0
# 1          2                             Super Mario Bros.      NES  1985.0
# 2          3                                Mario Kart Wii      Wii  2008.0
# 3          4                             Wii Sports Resort      Wii  2009.0
# 6          7                         New Super Mario Bros.       DS  2006.0
# ...      ...                                           ...      ...     ...
# 12123  12125                                  Mario Tennis      Wii  2010.0
# 12770  12772  Dance Dance Revolution: Mario Mix (JP sales)       GC  2005.0
# 14626  14629                                    Calcio Bit      GBA  2006.0
# 14968  14971                                Teddy Together      3DS  2016.0
# 15991  15994                       Donkey Kong Jungle Beat      Wii  2008.0
#
# ...

# %%
grouped = nin1.groupby(['Genre', 'Year'], as_index=False).agg({'Global_Sales' : 'sum'})
grouped
# Out:
#         Genre    Year  Global_Sales
# 0    Fighting  1987.0          5.42
# 1    Fighting  1993.0          2.00
# 2    Fighting  1995.0          3.20
# 3    Fighting  1996.0          0.99
# 4    Fighting  1999.0          5.55
# ..        ...     ...           ...
# 109    Sports  2010.0          2.18
# 110    Sports  2012.0          1.05
# 111    Sports  2013.0          1.69
# 112    Sports  2014.0          0.88
# 113    Sports  2015.0          0.45
#
# [114 rows x 3 columns]

# %%
ax = sns.lineplot(data=grouped, x = 'Year', y = 'Global_Sales', hue = 'Genre')
