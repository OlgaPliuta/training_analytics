# %%
import pandas as pd
import os

# %%
path_inn = 'shared/homeworks/python_ds_miniprojects/4_inn/inn.xls'
path_needed = 'shared/homeworks/python_ds_miniprojects/4_inn/necessary_inn.txt'

# %%
inns = pd.read_excel(path_inn)
inns.head()
# Out:
#    Unnamed: 0  #                                    name     reg_number  \
# 0           0  0         ЗАО «Власова, Макаров и Шашков»  1143692580560
# 1           1  1  РАО «Тимофеева, Алексеева и Кузнецова»  9342309660697
# 2           2  2                      РАО «Юдин-Ефимова»  1277485323451
# 3           3  3                   Доронин Инкорпорэйтед  7139161431511
# 4           4  4    Объединенная энергетическая компания  6114798049639
#
#                                              address  \
# 0  д. Кирово-Чепецк, пр. Металлургов, д. 537 к. 3...
# 1  г. Арзамас, наб. Фестивальная, д. 7 стр. 8/2, ...
# 2  п. Меренга, алл. Достоевского, д. 3/4 к. 497, ...
# 3  д. Иваново, ул. Красных Партизан, д. 83 к. 4, ...
# 4           к. Энгельс, наб. Шишкина, д. 120, 823828
#
#                           head              head_job      head_inn  \
# 0        Жданов Карл Виленович              Маммолог  109092209811
# 1  Рожков Харлампий Алексеевич           Воспитатель  704229465069
# ...

# %%
needed = pd.read_csv(path_needed, header=None)
needed.columns = ['head_inn']

needed
# Out:
#          head_inn
# 0    394609645484
# 1    281578625230
# 2    923769811917
# 3    998694734508
# 4    271011690615
# ..            ...
# 110  664306216794
# 111  991951385204
# 112  129413497752
# 113  447901012904
# 114  634037614688
#
# [115 rows x 1 columns]

# %% [markdown]
# ## Отбираем ИНН, которые есть в needed:

# %%
selected_inn = inns.merge(needed, on='head_inn')
selected_inn
# Out:
#      Unnamed: 0     #                                name     reg_number  \
# 0            47    47                      Пермэнергосбыт  6417532956774
# 1            76    76              ЗАО «Кабанова Ковалев»  9343329412518
# 2            77    77                             Неофарм  3813743111150
# 3            85    85                         Арконик СМЗ  7465966885549
# 4            90    90                     Фармперспектива  6205521489390
# ..          ...   ...                                 ...            ...
# 110        2059  2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 111        2074  2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 112        2089  2089                  НПО «Зимин Иванов»  6791957421599
# 113        2106  2106                           Юдина Лтд  5012825137426
# 114        2108  2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                address  \
# ...

# %%
selected_inn['income,RUB'].sum()
# Out:
# 6104522627393

# %%
selected_inn.to_csv(index=False)
# Out:
# 'Unnamed: 0,#,name,reg_number,address,head,head_job,head_inn,phone,email,site,registration_date,nalogoplatelschik_code,oktmo_code,okato_code,registration_region,okato_name,field,"capital,RUB","income,RUB"\n47,47,Пермэнергосбыт,6417532956774,"ст. Слюдянка, пер. Брянский, д. 378 стр. 634, 790392",Емельян Феликсович Зайцев,Релайтер,175482780898,8 833 729 83 14,boleslav28@gmail.com,krilova.net,1986-03-20,1998-02-11,47158105405,10234283083,Novosilikatnyy,"г. Кропоткин (Краснод.), пр. Лесный, д. 8/3 к. 431, 768042",Разработка подробных результатов,44637351562,67534335517\n76,76,ЗАО «Кабанова Ковалев»,9343329412518,"с. Нарткала, ул. Верхняя, д. 68 стр. 1, 393309",Геннадий Денисович Григорьев,Бондарь,120708914823,+7 455 632 1053,kapustinjulian@oao.com,ao.ru,2011-09-28,1983-11-10,20653722407,92544205998,Severodvinsk,"д. Москва, МГУ, бул. Транспортный, д. 75 стр. 7/1, 290123",Монетизация передовых действий,78570288945,19932336080\n77,77,Неофарм,3813743111150,"г. Долинск, ш. Московское, д. 25 к
# ...

# %%
wanted = needed['head_inn']
sel = inns.query('head_inn in @wanted')
sel
# Out:
#       Unnamed: 0     #                                name     reg_number  \
# 47            47    47                      Пермэнергосбыт  6417532956774
# 76            76    76              ЗАО «Кабанова Ковалев»  9343329412518
# 77            77    77                             Неофарм  3813743111150
# 85            85    85                         Арконик СМЗ  7465966885549
# 90            90    90                     Фармперспектива  6205521489390
# ...          ...   ...                                 ...            ...
# 2059        2059  2059    ЗАО «Кабанова, Титов и Бирюкова»  4405157155853
# 2074        2074  2074  ООО «Фомин, Симонова и Никифорова»  9213736030860
# 2089        2089  2089                  НПО «Зимин Иванов»  6791957421599
# 2106        2106  2106                           Юдина Лтд  5012825137426
# 2108        2108  2108                ООО «Хохлов Казаков»  9506828156265
#
#                                                 address  \
# ...

# %%
sel['income,RUB'].sum()
# Out:
# 6104522627393

# %%
inns.dtypes
# Out:
# Unnamed: 0                 int64
# #                          int64
# name                      object
# reg_number                 int64
# address                   object
# head                      object
# head_job                  object
# head_inn                   int64
# phone                     object
# email                     object
# site                      object
# registration_date         object
# nalogoplatelschik_code    object
# oktmo_code                 int64
# okato_code                 int64
# registration_region       object
# okato_name                object
# field                     object
# capital,RUB                int64
# income,RUB                 int64
# dtype: object
